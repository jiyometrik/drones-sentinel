# %%
import numpy as np
from scipy import signal
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import os, glob
from datetime import datetime
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

sns.set_theme()

# %% [markdown]
# # testdrive
#
# it's just a simple testfile to stitch everything together

# %%
DATADIR = os.path.join(os.getcwd(), "data")
ZIPDIR = os.path.join(os.getcwd(), "data/zip")
SAMPLE_RATE = 100_000_000

# %% [markdown]
# ## step 1
# figure out how to extract data from the zipfiles,
# label them, and then put them into a format suitable for further ML

# %% [markdown]
# ### step 1.1
# extract all the zipfiles and obtain our raw iq and ifft files

# %%
def unload_zip_files(zipdir, extractdir) -> None:
    """unload zip files in the respective zip directory"""
    # list filenames that end with .zip
    pattern = os.path.join(zipdir, "**", "*.zip")
    zipfiles = glob.glob(pattern, recursive=True)

    # unzip all zipfiles found
    for zfile in zipfiles:
        try:
            with zipfile.ZipFile(zfile, "r") as zip_ref:
                zip_ref.extractall(extractdir)
            print(
                f"Successfully extracted all files from '{zipdir}' to '{extractdir}'."
            )
        except zipfile.BadZipFile:
            print(f"Error: '{zfile}' is not a valid ZIP file.")
        except FileNotFoundError:
            print(f"Error: The file '{zfile}' was not found.")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")


for _ in tqdm(range(100)):
    unload_zip_files(ZIPDIR, DATADIR)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 8399.19it/s]

# %% [markdown]
# ### step 1.2
# come up with helper functions to
# * read a raw IFFT file
# * compute its Welch PSD
# * compute its STFT (short-term Fourier transform)
# <!-- read the raw ifft file given some dataformat and the filepath -->

# %%
def read_raw_ifft(file_path, data_format):
    """
    read raw binary data from file and return as numpy array after IFFT
    """
    # Map format strings to numpy dtypes and struct formats
    format_map = {
        "float32": (np.float32, "f"),
        "float64": (np.float64, "d"),
        "int16": (np.int16, "h"),
        "int32": (np.int32, "i"),
        "complex64": (np.complex64, None),  # Special handling for complex
        "complex128": (np.complex128, None),
    }

    if data_format not in format_map:
        raise ValueError(f"Unsupported data format: {data_format}")

    try:
        with open(file_path, "rb") as f:
            raw_data = f.read()

        # handle complex data (interleaved real/imaginary)
        if data_format in ["complex64", "complex128"]:
            # each complex number is 2 float32 values
            float_data = np.frombuffer(
                raw_data,
                dtype=(np.float32 if data_format == "complex64" else np.float64),
            )
            data = float_data[::2] + 1j * float_data[1::2]
        else:
            # Handle real data types
            dtype, _ = format_map[data_format]
            data = np.frombuffer(raw_data, dtype=dtype)

        return data

    except FileNotFoundError:
        raise FileNotFoundError(f"File not found: {file_path}")
    except Exception as e:
        raise RuntimeError(f"Error reading file: {str(e)}")

# %%
test_ifft = read_raw_ifft(
    "data/DatasetCollection_Scis1Subway_060825/DjiRcN1_Ifft_50m_1_40_40_01/sweep/1.ifft",
    "float64",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 19, in read_raw_ifft(file_path, data_format)
#      18 try:
# ---> 19     with open(file_path, "rb") as f:
#      20         raw_data = f.read()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/DatasetCollection_Scis1Subway_060825/DjiRcN1_Ifft_50m_1_40_40_01/sweep/1.ifft'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test_ifft = read_raw_ifft(
#       2     "data/DatasetCollection_Scis1Subway_060825/DjiRcN1_Ifft_50m_1_40_40_01/sweep/1.ifft",
#       3     "float64",
#       4 )
#
# Cell In[4], line 38, in read_raw_ifft(file_path, data_format)
#      35     return data
#      37 except FileNotFoundError:
# ---> 38     raise FileNotFoundError(f"File not found: {file_path}")
#      39 except Exception as e:
#      40     raise RuntimeError(f"Error reading file: {str(e)}")
#
# FileNotFoundError: File not found: data/DatasetCollection_Scis1Subway_060825/DjiRcN1_Ifft_50m_1_40_40_01/sweep/1.ifft

# %%
def compute_stft(iq_data, sample_rate_hz, nperseg=8192, visualise=False):
    """
    computes the short-time fourier transform of the given IQ data
    """
    f, t, Zxx = signal.stft(
        iq_data,
        fs=sample_rate_hz,
        nperseg=nperseg,
        return_onesided=False,  # Two-sided spectrum
    )

    # Shift frequencies to center around 0 Hz
    f = np.fft.fftshift(f)
    Zxx = np.fft.fftshift(Zxx, axes=0)

    if visualise:
        print("Plotting STFT")
        plt.figure(figsize=(12, 8))
        plt.pcolormesh(t, f / 1e6, np.abs(Zxx), shading="gouraud")
        plt.title("Short-Time Fourier Transform (STFT)")
        plt.xlabel("Time [s]")
        plt.ylabel("Frequency [MHz]")
        plt.colorbar(label="Magnitude")
        plt.grid(True)
        plt.show()

    return f, t, Zxx

# %%
f_, t_, Zxx_ = compute_stft(test_ifft, SAMPLE_RATE, nperseg=512, visualise=True)
# Out:
# Plotting STFT

# %%
def compute_welch_psd(
    iq_data, sample_rate_hz, window="hann", nperseg=8192, visualise=False
):
    """
    Compute the Welch power spectral density (PSD) of the IQ data.
    """
    f, Pxx = signal.welch(iq_data, fs=sample_rate_hz, nperseg=nperseg, window=window)

    if visualise:
        print("Plotting wPSD")
        plt.figure(figsize=(12, 8))
        plt.semilogy(f, Pxx)
        plt.title("Welch's Power Spectral Density (wPSD)")
        plt.xlabel("Frequency [MHz]")
        plt.ylabel("Power [V2/Hz]")
        plt.show()

    return f, Pxx

# %%
f_test, Pxx_test = compute_welch_psd(
    iq_data=test_ifft,
    sample_rate_hz=SAMPLE_RATE,
    nperseg=512,
    visualise=True,
)
# Out:
# Plotting wPSD

# %% [markdown]
# ## step 1.3
# create a `pandas.DataFrame` that contains
# - the PSD and STFT of each IFFT sweep
# - relevant meta info (drone type, operating frequency, distance, and gain)

# %%
import pandas as pd

# create a dictionary that will later be converted to a DataFrame
ifft_dict = {
    "psd": [],
    "stft": [],
    "dronetype": [],
    "freq_ghz": [],
    "distance_m": [],
    "gain_mhz": [],
}


def find_all_iffts(datadir) -> list:
    """obtain the paths of all *.ifft files; we can crawl through them"""
    pattern = os.path.join(datadir, "**", "*.ifft")
    iq_files = glob.glob(pattern, recursive=True)
    return iq_files


ifft_fnames = find_all_iffts(DATADIR)
for fname in ifft_fnames:
    # read the raw ifft file, and compute its PSD and STFT
    ifft_clean = read_raw_ifft(fname, data_format="float64")
    f, Pxx = compute_welch_psd(
        ifft_clean, sample_rate_hz=SAMPLE_RATE, nperseg=512, visualise=0
    )
    psd = np.stack((f, Pxx))
    freq, t, stft = compute_stft(
        ifft_clean, sample_rate_hz=SAMPLE_RATE, nperseg=512, visualise=0
    )

    # grab the metadata that's in the filename
    components = os.path.relpath(fname, DATADIR).split("\\")[1].split("_")

    # some folders were named without the operating frequency, use 0 as a standin
    if len(components) == 7:
        components.insert(2, "0")

    # grab the features we want... 
    dronetype = components[0]
    freq_ghz = int(components[2]) if int(components[2]) != 0 else np.nan
    distance_m = int(components[3].split("m")[0])
    gain_mhz = int(components[5])

    # ...and add them all to the dictionary
    ifft_dict["dronetype"].append(dronetype)
    ifft_dict["distance_m"].append(distance_m)
    ifft_dict["gain_mhz"].append(gain_mhz)
    ifft_dict["freq_ghz"].append(freq_ghz)
    ifft_dict["psd"].append(psd)
    ifft_dict["stft"].append(stft)

# convert the data dict to a dataframe!
ifft_df = pd.DataFrame(data=ifft_dict)
ifft_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 29
#      25 f, Pxx = compute_welch_psd(
#      26     ifft_clean, sample_rate_hz=SAMPLE_RATE, nperseg=512, visualise=0
#      27 )
#      28 psd = np.stack((f, Pxx))
# ---> 29 freq, t, stft = compute_stft(
#      30     ifft_clean, sample_rate_hz=SAMPLE_RATE, nperseg=512, visualise=0
#      31 )
#      33 # grab the metadata that's in the filename
#      34 components = os.path.relpath(fname, DATADIR).split("\\")[1].split("_")
#
# Cell In[103], line 5, in compute_stft(iq_data, sample_rate_hz, nperseg, visualise)
#       1 def compute_stft(iq_data, sample_rate_hz, nperseg=8192, visualise=False):
#       2     """
#       3     computes the short-time fourier transform of the given IQ data
#       4     """
# ----> 5     f, t, Zxx = signal.stft(
#       6         iq_data,
#       7         fs=sample_rate_hz,
#       8         nperseg=nperseg,
#       9         return_onesided=False,  # Two-sided spectrum
#      10     )
#      12     # Shift frequencies to center around 0 Hz
#      13     f = np.fft.fftshift(f)
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\signal\_spectral_py.py:1430, in stft(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, boundary, padded, axis, scaling)
#    1427 elif scaling != 'spectrum':
#    1428     raise ValueError(f"Parameter {scaling=} not in ['spectrum', 'psd']!")
# -> 1430 freqs, time, Zxx = _spectral_helper(x, x, fs, window, nperseg, noverlap,
#    1431                                     nfft, detrend, return_onesided,
#    1432                                     scaling=scaling, axis=axis,
#    1433                                     mode='stft', boundary=boundary,
#    1434                                     padded=padded)
#    1436 return freqs, time, Zxx
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\signal\_spectral_py.py:2118, in _spectral_helper(x, y, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode, boundary, padded)
#    2115     freqs = sp_fft.rfftfreq(nfft, 1/fs)
#    2117 # Perform the windowed FFTs
# -> 2118 result = _fft_helper(x, win, detrend_func, nperseg, noverlap, nfft, sides)
#    2120 if not same_data:
#    2121     # All the same operations on the y data
#    2122     result_y = _fft_helper(y, win, detrend_func, nperseg, noverlap, nfft,
#    2123                            sides)
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\signal\_spectral_py.py:2202, in _fft_helper(x, win, detrend_func, nperseg, noverlap, nfft, sides)
#    2200     result = result.real
#    2201     func = sp_fft.rfft
# -> 2202 result = func(result, n=nfft)
#    2204 return result
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\fft\_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      26 if fn is None:
#      27     return NotImplemented
# ---> 28 return fn(*args, **kwargs)
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\fft\_basic_backend.py:79, in fft(x, n, axis, norm, overwrite_x, workers, plan)
#      77 def fft(x, n=None, axis=-1, norm=None,
#      78         overwrite_x=False, workers=None, *, plan=None):
# ---> 79     return _execute_1D('fft', _pocketfft.fft, x, n=n, axis=axis, norm=norm,
#      80                        overwrite_x=overwrite_x, workers=workers, plan=plan)
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\fft\_basic_backend.py:32, in _execute_1D(func_str, pocketfft_func, x, n, axis, norm, overwrite_x, workers, plan)
#      30 if is_numpy(xp):
#      31     x = np.asarray(x)
# ---> 32     return pocketfft_func(x, n=n, axis=axis, norm=norm,
#      33                           overwrite_x=overwrite_x, workers=workers, plan=plan)
#      35 norm = _validate_fft_args(workers, plan, norm)
#      36 if hasattr(xp, 'fft'):
#
# File c:\Users\darre\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\fft\_pocketfft\basic.py:31, in c2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      27     raise ValueError(message)
#      29 out = (tmp if overwrite_x and tmp.dtype.kind == 'c' else None)
# ---> 31 return pfft.c2c(tmp, (axis,), forward, norm, out, workers)
#
# KeyboardInterrupt:

# %% [markdown]
# # step 2: model training
#
# try our best to train a CNN on the data that we've gathered.
# - $X$: `DataFrame["psd"]`
# - $y$: `DataFrame["dronetype"]`

# %% [markdown]
# ### step 2.1: dataset formation
#
# take the `pandas.DataFrame` we made previously and convert it to datasets and dataloaders
# in pytorch

# %%
class PSDDataset(Dataset):
    """
    custom IFFT data dataset using Welch's PSDs
    X: ifft_dict["psd"] (pandas.Series of numpy.ndarray)
    y: ifft_dict["dronetype"] (pandas.Series of int64)
    """

    def __init__(self, X, y):
        # WARN: what .tolist() does to the dimensions of the tensors is unclear, but prevents errors
        self.X = X.tolist() if isinstance(X, pd.Series) else X
        self.y = y.tolist() if isinstance(y, pd.Series) else y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        # only return torch.Tensors when called
        return torch.FloatTensor(self.X[idx]), torch.LongTensor([self.y[idx]]).squeeze()

# %%
classes = ifft_df["dronetype"].unique().tolist()
N_CLASSES = len(classes)
classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 classes = ifft_df["dronetype"].unique().tolist()
#       2 N_CLASSES = len(classes)
#       3 classes
#
# NameError: name 'ifft_df' is not defined

# %%
# assign numbers to drone classes
ifft_df["dronenum"] = ifft_df["dronetype"].apply(lambda x: classes.index(x))
# print(ifft_df["dronenum"])

# prepare data
X = np.stack(ifft_df["psd"].values)
X_flat = X.reshape(X.shape[0], -1)  
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat)
X = X_scaled.reshape(X.shape)

# encode labels
le = LabelEncoder()
y = le.fit_transform(ifft_df["dronetype"].values)

# split dataframe into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# ...then create datasets out of them
ds_train = PSDDataset(X_train, y_train)
ds_test = PSDDataset(X_test, y_test)

# and also dataloaders!
dl_train = DataLoader(ds_train, batch_size=128, shuffle=True, num_workers=0)
dl_test = DataLoader(ds_test, batch_size=128, shuffle=False, num_workers=0)

ds_train, ds_test, dl_train, dl_test
# Out:
# (<__main__.PSDDataset at 0x1e5dccf0f50>,
#  <__main__.PSDDataset at 0x1e5dcdf05d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x1e5dc90b550>,
#  <torch.utils.data.dataloader.DataLoader at 0x1e5dc9add50>)

# %% [markdown]
# ### step 2.2: create a model
#
# come up with some CNN architecture.
# this can and should be tweaked in the future to yield better accuracies.

# %%
class PSDClassifier(nn.Module):
    def __init__(self, num_classes=N_CLASSES):
        super(PSDClassifier, self).__init__()

        self.conv1_3 = nn.Conv1d(2, 32, kernel_size=3, padding=1)
        self.conv1_5 = nn.Conv1d(2, 32, kernel_size=5, padding=2)
        self.conv1_7 = nn.Conv1d(2, 32, kernel_size=7, padding=3)
        self.bn1 = nn.BatchNorm1d(96)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv1d(96, 192, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm1d(192)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=2)  # -> (192, 64)

        self.conv3 = nn.Conv1d(192, 384, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(384)
        self.pool3 = nn.MaxPool1d(kernel_size=2, stride=2)

        # global avg pooling
        self.gap = nn.AdaptiveAvgPool1d(1)  # -> (256, 1)

        # fully connected layers
        self.fc1 = nn.Linear(384, 256)
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, 64)
        self.dropout2 = nn.Dropout(0.25)
        self.fc3 = nn.Linear(64, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        """generic forward function"""
        x1, x2, x3 = self.conv1_3(x), self.conv1_5(x), self.conv1_7(x)
        x = torch.cat([x1, x2, x3], dim=1)
        x = self.pool1(self.relu(self.bn1(x)))

        x = self.pool2(self.relu(self.bn2(self.conv2(x))))
        x = self.pool3(self.relu(self.bn3(self.conv3(x))))
        x = self.gap(x).view(x.size(0), -1)  # flatten

        x = self.dropout1(self.relu(self.fc1(x)))
        x = self.dropout2(self.relu(self.fc2(x)))
        x = self.fc3(x)

        return x

# %%
N_EPOCHS = 50
LR = 0.001

simple_performance_stats = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": [],
}

# %%
def model_train(model, train_loader, val_loader, n_epochs=N_EPOCHS, lr=LR):
    logs = {
        "epoch": [],
        "train_loss": [],
        "train_acc": [],
        "val_loss": [],
        "val_acc": [],
    }
    """training loop"""
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimiser = optim.SGD(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimiser, mode="min", factor=0.5, patience=5
    )

    best_val_acc = 0.0

    for epoch in range(n_epochs):
        # training phase starts here
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimiser.zero_grad()

            # feed inputs and gather outputs from model
            outputs = model(inputs)

            # calculate loss
            loss = criterion(outputs, labels)
            loss.backward()
            optimiser.step()

            train_loss += loss.item()
            _, preds = torch.max(outputs.data, 1)
            train_total += labels.size(0)  # tabulate how many we've trained
            train_correct += (preds == labels).sum().item()  # and how many were correct

        # evaluation phase starts here
        model.eval()
        val_loss, val_total, val_correct = 0.0, 0, 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # same as before; now we're tracking validation loss
                val_loss += loss.item()
                _, preds = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (preds == labels).sum().item()

        # calculate acc in [0, 1]
        train_acc = train_correct / train_total
        val_acc = val_correct / val_total

        scheduler.step(val_loss)

        # keep a running maximum accuracy, and save the best model so far
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            fname = f"{model.__class__.__name__}_{datetime.now().strftime('%d%m%Y')}.pth"
            torch.save(
                model.state_dict(),
                os.path.join("model_states/", fname),
            )

        # log all the metrcis per epoch
        train_loss /= len(train_loader)
        val_loss /= len(val_loader)

        print(f"EPOCH [{epoch+1}/{n_epochs}]")
        print(f"train_loss: {train_loss:.4f}, train_acc: {train_acc:.4f}")
        print(f"val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}")

        # keep track of performance metrics
        logs["epoch"].append(epoch + 1)
        logs["train_loss"].append(train_loss)
        logs["train_acc"].append(train_acc)
        logs["val_loss"].append(val_loss)
        logs["val_acc"].append(val_acc)

# %%
# test the model
simple_model = PSDClassifier(num_classes=N_CLASSES)
trained_model = model_train(simple_model, dl_train, dl_test, logs=simple_performance_stats)
# Out:
# EPOCH [1/50]
# train_loss: 1.3573, train_acc: 0.3241
# val_loss: 1.3728, val_acc: 0.0934
# EPOCH [2/50]
# train_loss: 1.3668, train_acc: 0.3183
# val_loss: 1.3704, val_acc: 0.1142
# EPOCH [3/50]
# train_loss: 1.3551, train_acc: 0.3933
# val_loss: 1.3671, val_acc: 0.1246
# EPOCH [4/50]
# train_loss: 1.3501, train_acc: 0.4210
# val_loss: 1.3632, val_acc: 0.4256
# EPOCH [5/50]
# train_loss: 1.3490, train_acc: 0.4602
# val_loss: 1.3585, val_acc: 0.4533
# EPOCH [6/50]
# train_loss: 1.3469, train_acc: 0.4637
# val_loss: 1.3537, val_acc: 0.5156
# EPOCH [7/50]
# train_loss: 1.3409, train_acc: 0.4775
# val_loss: 1.3492, val_acc: 0.5363
# EPOCH [8/50]
# train_loss: 1.3403, train_acc: 0.4948
# val_loss: 1.3458, val_acc: 0.5363
# EPOCH [9/50]
# train_loss: 1.3344, train_acc: 0.5029
# val_loss: 1.3423, val_acc: 0.5363
# EPOCH [10/50]
# train_loss: 1.3362, train_acc: 0.5156
# val_loss: 1.3393, val_acc: 0.5363
# EPOCH [11/50]
# train_loss: 1.3286, train_acc: 0.5144
# val_loss: 1.3364, val_acc: 0.5363
# EPOCH [12/50]
# train_loss: 1.3318, train_acc: 0.5190
# val_loss: 1.3345, val_acc: 0.5363
# EPOCH [13/50]
# train_loss: 1.3290, train_acc: 0.5271
# val_loss: 1.3322, val_acc: 0.5363
# EPOCH [14/50]
# train_loss: 1.3268, train_acc: 0.5271
# val_loss: 1.3305, val_acc: 0.5363
# EPOCH [15/50]
# train_loss: 1.3221, train_acc: 0.5306
# val_loss: 1.3282, val_acc: 0.5363
# EPOCH [16/50]
# train_loss: 1.3219, train_acc: 0.5306
# val_loss: 1.3282, val_acc: 0.5363
# EPOCH [17/50]
# train_loss: 1.3189, train_acc: 0.5329
# val_loss: 1.3254, val_acc: 0.5363
# EPOCH [18/50]
# train_loss: 1.3190, train_acc: 0.5306
# val_loss: 1.3252, val_acc: 0.5363
# EPOCH [19/50]
# train_loss: 1.3149, train_acc: 0.5340
# val_loss: 1.3224, val_acc: 0.5363
# EPOCH [20/50]
# train_loss: 1.3128, train_acc: 0.5352
# val_loss: 1.3207, val_acc: 0.5363
# EPOCH [21/50]
# train_loss: 1.3139, train_acc: 0.5352
# val_loss: 1.3211, val_acc: 0.5363
# EPOCH [22/50]
# train_loss: 1.3140, train_acc: 0.5340
# val_loss: 1.3176, val_acc: 0.5363
# EPOCH [23/50]
# train_loss: 1.3129, train_acc: 0.5329
# val_loss: 1.3164, val_acc: 0.5363
# EPOCH [24/50]
# train_loss: 1.3039, train_acc: 0.5363
# val_loss: 1.3120, val_acc: 0.5363
# EPOCH [25/50]
# train_loss: 1.2998, train_acc: 0.5363
# val_loss: 1.3096, val_acc: 0.5363
# EPOCH [26/50]
# train_loss: 1.2979, train_acc: 0.5363
# val_loss: 1.3095, val_acc: 0.5363
# EPOCH [27/50]
# train_loss: 1.3029, train_acc: 0.5363
# val_loss: 1.3074, val_acc: 0.5363
# EPOCH [28/50]
# train_loss: 1.2997, train_acc: 0.5352
# val_loss: 1.3052, val_acc: 0.5363
# EPOCH [29/50]
# train_loss: 1.2991, train_acc: 0.5363
# val_loss: 1.3026, val_acc: 0.5363
# EPOCH [30/50]
# train_loss: 1.2979, train_acc: 0.5363
# val_loss: 1.3040, val_acc: 0.5363
# EPOCH [31/50]
# train_loss: 1.2942, train_acc: 0.5363
# val_loss: 1.3012, val_acc: 0.5363
# EPOCH [32/50]
# train_loss: 1.2912, train_acc: 0.5363
# val_loss: 1.2991, val_acc: 0.5363
# EPOCH [33/50]
# train_loss: 1.2891, train_acc: 0.5363
# val_loss: 1.2957, val_acc: 0.5363
# EPOCH [34/50]
# train_loss: 1.2877, train_acc: 0.5363
# val_loss: 1.2935, val_acc: 0.5363
# EPOCH [35/50]
# train_loss: 1.2894, train_acc: 0.5363
# val_loss: 1.2963, val_acc: 0.5363
# EPOCH [36/50]
# train_loss: 1.2835, train_acc: 0.5363
# val_loss: 1.2936, val_acc: 0.5363
# EPOCH [37/50]
# train_loss: 1.2859, train_acc: 0.5363
# val_loss: 1.2909, val_acc: 0.5363
# EPOCH [38/50]
# train_loss: 1.2865, train_acc: 0.5363
# val_loss: 1.2879, val_acc: 0.5363
# EPOCH [39/50]
# train_loss: 1.2806, train_acc: 0.5363
# val_loss: 1.2858, val_acc: 0.5363
# EPOCH [40/50]
# train_loss: 1.2831, train_acc: 0.5352
# val_loss: 1.2847, val_acc: 0.5363
# EPOCH [41/50]
# train_loss: 1.2758, train_acc: 0.5363
# val_loss: 1.2812, val_acc: 0.5363
# EPOCH [42/50]
# train_loss: 1.2780, train_acc: 0.5363
# val_loss: 1.2806, val_acc: 0.5363
# EPOCH [43/50]
# train_loss: 1.2731, train_acc: 0.5363
# val_loss: 1.2792, val_acc: 0.5363
# EPOCH [44/50]
# train_loss: 1.2686, train_acc: 0.5363
# val_loss: 1.2771, val_acc: 0.5363
# EPOCH [45/50]
# train_loss: 1.2707, train_acc: 0.5363
# val_loss: 1.2742, val_acc: 0.5363
# EPOCH [46/50]
# train_loss: 1.2704, train_acc: 0.5363
# val_loss: 1.2742, val_acc: 0.5363
# EPOCH [47/50]
# train_loss: 1.2679, train_acc: 0.5363
# val_loss: 1.2733, val_acc: 0.5363
# EPOCH [48/50]
# train_loss: 1.2624, train_acc: 0.5363
# val_loss: 1.2710, val_acc: 0.5363
# EPOCH [49/50]
# train_loss: 1.2599, train_acc: 0.5363
# val_loss: 1.2669, val_acc: 0.5363
# EPOCH [50/50]
# train_loss: 1.2617, train_acc: 0.5363
# val_loss: 1.2669, val_acc: 0.5363

# %%
sns.lineplot(data=pd.DataFrame(simple_performance_stats))
# Out:
# <Axes: >
